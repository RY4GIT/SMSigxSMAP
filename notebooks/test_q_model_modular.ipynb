# %%
import os
import sys
import multiprocessing as mp
from configparser import ConfigParser
import time


sys.path.append('../analysis')
from Agent import Agent

# %%
cfg = ConfigParser()
cfg.read("../analysis/config.ini")
agent = Agent(cfg=cfg)
agent.initialize()
# Out:
# Number of pixels in the spatial extent: 10920
# Number of pixels without openwater: 9596

# %% [markdown]
# [ 53, 163]
# [99, 205]

# %%
results = agent.run([ 99, 205])
# Out:
# Currently processing pixel [53, 163]
# Event separation success at (53, 163): 1 events detected

# %%
agent.finalize(results)
