# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr

from functions import q_drydown, exponential_drydown, loss_model

# %%
# Define variables 
theta = np.arange(0, 1, 0.01)
t = np.arange(0, 10, 0.1)

# Define parameters
k= 1
q0 = 1
q = 3
delta_theta = 1
theta_w = 0
tau = 3

# %%
fig = plt.figure(figsize=(8,4))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(theta, loss_model(theta, q=1.5, k=-1.), '.')
ax1.plot(theta, loss_model(theta, q=1., k=-1.), '.')
ax1.plot(theta, loss_model(theta, q=0.5, k=-1.), '.')

t = np.arange(0, 10.1, 0.1)

ax2.plot(theta, q_drydown(t, q=1.5, k=-1.), '.')
ax2.plot(theta, q_drydown(t, q=0.5, k=-1.), '.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 16
#      10 t = np.arange(0, 10.1, 0.1)
#      12 # ax2.plot(theta, calc_theta_bryn(t, q=1.5, k=-1.), '.')
#      13 # ax2.plot(theta, calc_theta_bryn(t, q=1., k=-1.), '.')
#      14 # ax2.plot(theta, calc_theta_bryn(t, q=0.5, k=-1.), '.')
# ---> 16 ax2.plot(theta, q_drydown(t, q=1.5, k=-1.), '.')
#      17 ax2.plot(theta, q_drydown(t, q=0.5, k=-1.), '.')
#
# TypeError: q_drydown() missing 1 required positional argument: 'delta_theta'
