# %% [markdown]
# # Customize and Access NSIDC DAAC Data
#
# This notebook will walk you through how to programmatically access data from the NASA National Snow and Ice Data Center Distributed Active Archive Center (NSIDC DAAC) using spatial and temporal filters, as well as how to request customization services including subsetting, reformatting, and reprojection. No Python experience is necessary; each code cell will prompt you with the information needed to configure your data request. The notebook will print the resulting API command that can be used in a command line, browser, or in Python as executed below.

# %% [markdown]
# ### Import packages

# %%
import requests
import json
import zipfile
import io
import math
import os
import glob
import shutil
import pprint
import re
import time
from statistics import mean
# %matplotlib inline

short_name = 'SPL3SMP_E'
out_path = r'..\1_data'

if not os.path.exists(out_path):
   os.makedirs(out_path)

if not os.path.exists(os.path.join(out_path, short_name)):
   os.makedirs(os.path.join(out_path, short_name))

# %% [markdown]
# ### Delete existing files if you need

# %%
files = glob.glob(os.path.join(out_path, short_name, '*.nc'), recursive=True)
files
for f in files:
    try:
        os.remove(f)
    except OSError as e:
        print("Error: %s : %s" % (f, e.strerror))

# %% [markdown]
# ### Input Earthdata Login credentials
#
# An Earthdata Login account is required to access data from the NSIDC DAAC. If you do not already have an Earthdata Login account, visit http://urs.earthdata.nasa.gov to register.

# %%
my_credential_path = "./auth.json"
with open(my_credential_path, 'r') as infile:
    my_credentials = json.load(infile)
    
uid = my_credentials['username'] # Enter Earthdata Login user name
pswd = my_credentials['password'] # Enter Earthdata Login password
email = my_credentials['email'] # Enter Earthdata login email

# %% [markdown]
# ### Select data set and determine version number
#
# Data sets are selected by data set IDs (e.g. MOD10A1), whic are also referred to as a "short name". These short names are located at the top of each NSIDC data set landing page in gray above the full title.

# %%
# Get json response from CMR collection metadata

params = {
    'short_name': short_name
}

cmr_collections_url = 'https://cmr.earthdata.nasa.gov/search/collections.json'
response = requests.get(cmr_collections_url, params=params)
results = json.loads(response.content)

# Find all instances of 'version_id' in metadata and print most recent version number
versions = [el['version_id'] for el in results['feed']['entry']]
latest_version = max(versions)
print('The most recent version of ', short_name, ' is ', latest_version)
# Out:
# The most recent version of  SPL3SMP_E  is  005

# %% [markdown]
# ### Select time period of interest

# %%
#Input temporal range 

# Somehow only up to 2020-10-26 was downloaded in the first try

# start_date = '2015-03-31'# input('Input start date in yyyy-MM-dd format: ')
# start_date = '2020-10-27'# input('Input start date in yyyy-MM-dd format: ')
start_date = '2019-06-20'# input('Input start date in yyyy-MM-dd format: ')
start_time = '00:00:00' # input('Input start time in HH:mm:ss format: ')
end_date = '2019-07-22' # input('Input end date in yyyy-MM-dd format: ')
end_time = '00:00:00' # input('Input end time in HH:mm:ss format: ')

temporal = start_date + 'T' + start_time + 'Z' + ',' + end_date + 'T' + end_time + 'Z'

# %% [markdown]
# ### Select area of interest
#
# #### Select bounding box or shapefile entry
#
# For all data sets, you can enter a bounding box to be applied to your file search. If you are interested in ICESat-2 data, you may also apply a spatial boundary based on a vector-based spatial data file.

# %%
# Enter spatial coordinates in decimal degrees, with west longitude and south latitude reported as negative degrees. Do not include spaces between coordinates.
# Example over the state of Colorado: -109,37,-102,41

# bounding_box = '147.534,-35.324,147.535,-35.323' #input('Input spatial coordinates in the following order: lower left longitude,lower left latitude,upper right longitude,upper right latitude. Leave blank if you wish to provide a vector-based spatial file for ICESat-2 search and subsetting:')

# %% [markdown]
# ### Determine how many granules exist over this time and area of interest.

# %%
# Create CMR parameters used for granule search. Modify params depending on bounding_box or polygon input.

granule_search_url = 'https://cmr.earthdata.nasa.gov/search/granules'
aoi='1'
if aoi == '1':
# bounding box input:
    search_params = {
    'short_name': short_name,
    'version': latest_version,
    'temporal': temporal,
    'page_size': 100,
    'page_num': 1
    }

granules = []
headers={'Accept': 'application/json'}
while True:
    response = requests.get(granule_search_url, params=search_params, headers=headers)
    results = json.loads(response.content)

    if len(results['feed']['entry']) == 0:
        # Out of results, so break out of loop
        break

    # Collect results and increment page_num
    granules.extend(results['feed']['entry'])
    search_params['page_num'] += 1

print('There are', len(granules), 'granules of', short_name, 'version', latest_version, 'over my area and time of interest.')
# Out:
# There are 0 granules of SPL3SMP_E version 005 over my area and time of interest.

# %% [markdown]
# ### Determine the average size of those granules as well as the total volume

# %%
granule_sizes = [float(granule['granule_size']) for granule in granules]
print(f'The average size of each granule is {mean(granule_sizes):.2f} MB and the total size of all {len(granules)} granules is {sum(granule_sizes):.2f} MB')
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# Cell In [68], line 2
#       1 granule_sizes = [float(granule['granule_size']) for granule in granules]
# ----> 2 print(f'The average size of each granule is {mean(granule_sizes):.2f} MB and the total size of all {len(granules)} granules is {sum(granule_sizes):.2f} MB')
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\statistics.py:328, in mean(data)
#     326 n = len(data)
#     327 if n < 1:
# --> 328     raise StatisticsError('mean requires at least one data point')
#     329 T, total, count = _sum(data)
#     330 assert count == n
#
# StatisticsError: mean requires at least one data point

# %% [markdown]
# Note that subsetting, reformatting, or reprojecting can alter the size of the granules if those services are applied to your request.

# %% [markdown]
# ### Select the subsetting, reformatting, and reprojection services enabled for your data set of interest.

# %% [markdown]
# The NSIDC DAAC supports customization services on many of our NASA Earthdata mission collections. Let's discover whether or not our data set has these services available. If services are available, we will also determine the specific service options supported for this data set and select which of these services we want to request.

# %% [markdown]
# ### Query the service capability endpoint to gather service information needed below

# %%
# Query service capability URL 
from xml.etree import ElementTree as ET
capability_url = f'https://n5eil02u.ecs.nsidc.org/egi/capabilities/{short_name}.{latest_version}.xml'

# Create session to store cookie and pass credentials to capabilities url
session = requests.session()
s = session.get(capability_url)
response = session.get(s.url,auth=(uid, pswd))
root = ET.fromstring(response.content)

# %%
#collect lists with each service option
subagent = [subset_agent.attrib for subset_agent in root.iter('SubsetAgent')]
if len(subagent) > 0 :

    # variable subsetting
    variables = [SubsetVariable.attrib for SubsetVariable in root.iter('SubsetVariable')]  
    variables_raw = [variables[i]['value'] for i in range(len(variables))]
    variables_join = [''.join(('/',v)) if v.startswith('/') == False else v for v in variables_raw] 
    variable_vals = [v.replace(':', '/') for v in variables_join]

    # reformatting
    formats = [Format.attrib for Format in root.iter('Format')]
    format_vals = [formats[i]['value'] for i in range(len(formats))]
    format_vals.remove('')

    # reprojection options
    projections = [Projection.attrib for Projection in root.iter('Projection')]
    
variables
# Out:
# [{'value': 'Soil_Moisture_Retrieval_Data_AM',
#   'label': 'Soil_Moisture_Retrieval_Data_AM',
#   'selected': 'false',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:albedo',
#   'label': 'albedo',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:albedo_dca',
#   'label': 'albedo_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:albedo_scah',
#   'label': 'albedo_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:albedo_scav',
#   'label': 'albedo_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:boresight_incidence',
#   'label': 'boresight_incidence',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:bulk_density',
#   'label': 'bulk_density',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:clay_fraction',
#   'label': 'clay_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:EASE_column_index',
#   'label': 'EASE_column_index',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:EASE_row_index',
#   'label': 'EASE_row_index',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:freeze_thaw_fraction',
#   'label': 'freeze_thaw_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:grid_surface_status',
#   'label': 'grid_surface_status',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:latitude',
#   'label': 'latitude',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:latitude_centroid',
#   'label': 'latitude_centroid',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:longitude',
#   'label': 'longitude',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:longitude_centroid',
#   'label': 'longitude_centroid',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:radar_water_body_fraction',
#   'label': 'radar_water_body_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:retrieval_qual_flag',
#   'label': 'retrieval_qual_flag',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:retrieval_qual_flag_dca',
#   'label': 'retrieval_qual_flag_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:retrieval_qual_flag_scah',
#   'label': 'retrieval_qual_flag_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:retrieval_qual_flag_scav',
#   'label': 'retrieval_qual_flag_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:roughness_coefficient',
#   'label': 'roughness_coefficient',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:roughness_coefficient_dca',
#   'label': 'roughness_coefficient_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:roughness_coefficient_scah',
#   'label': 'roughness_coefficient_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:roughness_coefficient_scav',
#   'label': 'roughness_coefficient_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:soil_moisture',
#   'label': 'soil_moisture',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:soil_moisture_dca',
#   'label': 'soil_moisture_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:soil_moisture_error',
#   'label': 'soil_moisture_error',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:soil_moisture_scah',
#   'label': 'soil_moisture_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:soil_moisture_scav',
#   'label': 'soil_moisture_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:static_water_body_fraction',
#   'label': 'static_water_body_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:surface_flag',
#   'label': 'surface_flag',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:surface_temperature',
#   'label': 'surface_temperature',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:surface_water_fraction_mb_h',
#   'label': 'surface_water_fraction_mb_h',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:surface_water_fraction_mb_v',
#   'label': 'surface_water_fraction_mb_v',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_3_corrected',
#   'label': 'tb_3_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_4_corrected',
#   'label': 'tb_4_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_h_corrected',
#   'label': 'tb_h_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_h_uncorrected',
#   'label': 'tb_h_uncorrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_qual_flag_3',
#   'label': 'tb_qual_flag_3',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_qual_flag_4',
#   'label': 'tb_qual_flag_4',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_qual_flag_h',
#   'label': 'tb_qual_flag_h',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_qual_flag_v',
#   'label': 'tb_qual_flag_v',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_time_seconds',
#   'label': 'tb_time_seconds',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_time_utc',
#   'label': 'tb_time_utc',
#   'selected': 'false',
#   'excludeFormat': 'GeoTIFF,HDF-EOS5,KML,NetCDF-3',
#   'excludeProjection': 'GEOGRAPHIC,NO_CHANGE,NORTH POLAR STEREOGRAPHIC,SOUTH POLAR STEREOGRAPHIC,UNIVERSAL TRANSVERSE MERCATOR',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_v_corrected',
#   'label': 'tb_v_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:tb_v_uncorrected',
#   'label': 'tb_v_uncorrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:vegetation_opacity',
#   'label': 'vegetation_opacity',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:vegetation_opacity_dca',
#   'label': 'vegetation_opacity_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:vegetation_opacity_scah',
#   'label': 'vegetation_opacity_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:vegetation_opacity_scav',
#   'label': 'vegetation_opacity_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_AM:vegetation_water_content',
#   'label': 'vegetation_water_content',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM',
#   'label': 'Soil_Moisture_Retrieval_Data_PM',
#   'selected': 'false',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:albedo_dca_pm',
#   'label': 'albedo_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:albedo_pm',
#   'label': 'albedo_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:albedo_scah_pm',
#   'label': 'albedo_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:albedo_scav_pm',
#   'label': 'albedo_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:boresight_incidence_pm',
#   'label': 'boresight_incidence_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:bulk_density_pm',
#   'label': 'bulk_density_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:clay_fraction_pm',
#   'label': 'clay_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:EASE_column_index_pm',
#   'label': 'EASE_column_index_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:EASE_row_index_pm',
#   'label': 'EASE_row_index_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:freeze_thaw_fraction_pm',
#   'label': 'freeze_thaw_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:grid_surface_status_pm',
#   'label': 'grid_surface_status_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:latitude_centroid_pm',
#   'label': 'latitude_centroid_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:latitude_pm',
#   'label': 'latitude_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:longitude_centroid_pm',
#   'label': 'longitude_centroid_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:longitude_pm',
#   'label': 'longitude_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:radar_water_body_fraction_pm',
#   'label': 'radar_water_body_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:retrieval_qual_flag_dca_pm',
#   'label': 'retrieval_qual_flag_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:retrieval_qual_flag_pm',
#   'label': 'retrieval_qual_flag_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:retrieval_qual_flag_scah_pm',
#   'label': 'retrieval_qual_flag_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:retrieval_qual_flag_scav_pm',
#   'label': 'retrieval_qual_flag_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:roughness_coefficient_dca_pm',
#   'label': 'roughness_coefficient_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:roughness_coefficient_pm',
#   'label': 'roughness_coefficient_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:roughness_coefficient_scah_pm',
#   'label': 'roughness_coefficient_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:roughness_coefficient_scav_pm',
#   'label': 'roughness_coefficient_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:soil_moisture_dca_pm',
#   'label': 'soil_moisture_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:soil_moisture_error_pm',
#   'label': 'soil_moisture_error_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:soil_moisture_pm',
#   'label': 'soil_moisture_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:soil_moisture_scah_pm',
#   'label': 'soil_moisture_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:soil_moisture_scav_pm',
#   'label': 'soil_moisture_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:static_water_body_fraction_pm',
#   'label': 'static_water_body_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:surface_flag_pm',
#   'label': 'surface_flag_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:surface_temperature_pm',
#   'label': 'surface_temperature_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:surface_water_fraction_mb_h_pm',
#   'label': 'surface_water_fraction_mb_h_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:surface_water_fraction_mb_v_pm',
#   'label': 'surface_water_fraction_mb_v_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_3_corrected_pm',
#   'label': 'tb_3_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_4_corrected_pm',
#   'label': 'tb_4_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_h_corrected_pm',
#   'label': 'tb_h_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_h_uncorrected_pm',
#   'label': 'tb_h_uncorrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_qual_flag_3_pm',
#   'label': 'tb_qual_flag_3_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_qual_flag_4_pm',
#   'label': 'tb_qual_flag_4_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_qual_flag_h_pm',
#   'label': 'tb_qual_flag_h_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_qual_flag_v_pm',
#   'label': 'tb_qual_flag_v_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_time_seconds_pm',
#   'label': 'tb_time_seconds_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_time_utc_pm',
#   'label': 'tb_time_utc_pm',
#   'selected': 'false',
#   'excludeFormat': 'GeoTIFF,HDF-EOS5,KML,NetCDF-3',
#   'excludeProjection': 'GEOGRAPHIC,NO_CHANGE,NORTH POLAR STEREOGRAPHIC,SOUTH POLAR STEREOGRAPHIC,UNIVERSAL TRANSVERSE MERCATOR',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_v_corrected_pm',
#   'label': 'tb_v_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:tb_v_uncorrected_pm',
#   'label': 'tb_v_uncorrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:vegetation_opacity_dca_pm',
#   'label': 'vegetation_opacity_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:vegetation_opacity_pm',
#   'label': 'vegetation_opacity_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:vegetation_opacity_scah_pm',
#   'label': 'vegetation_opacity_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:vegetation_opacity_scav_pm',
#   'label': 'vegetation_opacity_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_PM:vegetation_water_content_pm',
#   'label': 'vegetation_water_content_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM',
#   'label': 'Soil_Moisture_Retrieval_Data_Polar_AM',
#   'selected': 'false',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:albedo',
#   'label': 'albedo',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:albedo_dca',
#   'label': 'albedo_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:albedo_scah',
#   'label': 'albedo_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:albedo_scav',
#   'label': 'albedo_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:boresight_incidence',
#   'label': 'boresight_incidence',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:bulk_density',
#   'label': 'bulk_density',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:clay_fraction',
#   'label': 'clay_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:EASE_column_index',
#   'label': 'EASE_column_index',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:EASE_row_index',
#   'label': 'EASE_row_index',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:freeze_thaw_fraction',
#   'label': 'freeze_thaw_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:grid_surface_status',
#   'label': 'grid_surface_status',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:latitude',
#   'label': 'latitude',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:latitude_centroid',
#   'label': 'latitude_centroid',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:longitude',
#   'label': 'longitude',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:longitude_centroid',
#   'label': 'longitude_centroid',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:radar_water_body_fraction',
#   'label': 'radar_water_body_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:retrieval_qual_flag',
#   'label': 'retrieval_qual_flag',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:retrieval_qual_flag_dca',
#   'label': 'retrieval_qual_flag_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:retrieval_qual_flag_scah',
#   'label': 'retrieval_qual_flag_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:retrieval_qual_flag_scav',
#   'label': 'retrieval_qual_flag_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:roughness_coefficient',
#   'label': 'roughness_coefficient',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:roughness_coefficient_dca',
#   'label': 'roughness_coefficient_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:roughness_coefficient_scah',
#   'label': 'roughness_coefficient_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:roughness_coefficient_scav',
#   'label': 'roughness_coefficient_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:soil_moisture',
#   'label': 'soil_moisture',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:soil_moisture_dca',
#   'label': 'soil_moisture_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:soil_moisture_error',
#   'label': 'soil_moisture_error',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:soil_moisture_scah',
#   'label': 'soil_moisture_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:soil_moisture_scav',
#   'label': 'soil_moisture_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:static_water_body_fraction',
#   'label': 'static_water_body_fraction',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:surface_flag',
#   'label': 'surface_flag',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:surface_temperature',
#   'label': 'surface_temperature',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:surface_water_fraction_mb_h',
#   'label': 'surface_water_fraction_mb_h',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:surface_water_fraction_mb_v',
#   'label': 'surface_water_fraction_mb_v',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_3_corrected',
#   'label': 'tb_3_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_4_corrected',
#   'label': 'tb_4_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_h_corrected',
#   'label': 'tb_h_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_h_uncorrected',
#   'label': 'tb_h_uncorrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_qual_flag_3',
#   'label': 'tb_qual_flag_3',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_qual_flag_4',
#   'label': 'tb_qual_flag_4',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_qual_flag_h',
#   'label': 'tb_qual_flag_h',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_qual_flag_v',
#   'label': 'tb_qual_flag_v',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_time_seconds',
#   'label': 'tb_time_seconds',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_time_utc',
#   'label': 'tb_time_utc',
#   'selected': 'false',
#   'excludeFormat': 'GeoTIFF,HDF-EOS5,KML,NetCDF-3',
#   'excludeProjection': 'GEOGRAPHIC,NO_CHANGE,NORTH POLAR STEREOGRAPHIC,SOUTH POLAR STEREOGRAPHIC,UNIVERSAL TRANSVERSE MERCATOR',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_v_corrected',
#   'label': 'tb_v_corrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:tb_v_uncorrected',
#   'label': 'tb_v_uncorrected',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:vegetation_opacity',
#   'label': 'vegetation_opacity',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:vegetation_opacity_dca',
#   'label': 'vegetation_opacity_dca',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:vegetation_opacity_scah',
#   'label': 'vegetation_opacity_scah',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:vegetation_opacity_scav',
#   'label': 'vegetation_opacity_scav',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_AM:vegetation_water_content',
#   'label': 'vegetation_water_content',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM',
#   'label': 'Soil_Moisture_Retrieval_Data_Polar_PM',
#   'selected': 'false',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:albedo_dca_pm',
#   'label': 'albedo_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:albedo_pm',
#   'label': 'albedo_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:albedo_scah_pm',
#   'label': 'albedo_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:albedo_scav_pm',
#   'label': 'albedo_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:boresight_incidence_pm',
#   'label': 'boresight_incidence_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:bulk_density_pm',
#   'label': 'bulk_density_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:clay_fraction_pm',
#   'label': 'clay_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:EASE_column_index_pm',
#   'label': 'EASE_column_index_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:EASE_row_index_pm',
#   'label': 'EASE_row_index_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:freeze_thaw_fraction_pm',
#   'label': 'freeze_thaw_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:grid_surface_status_pm',
#   'label': 'grid_surface_status_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:latitude_centroid_pm',
#   'label': 'latitude_centroid_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:latitude_pm',
#   'label': 'latitude_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:longitude_centroid_pm',
#   'label': 'longitude_centroid_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:longitude_pm',
#   'label': 'longitude_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:radar_water_body_fraction_pm',
#   'label': 'radar_water_body_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:retrieval_qual_flag_dca_pm',
#   'label': 'retrieval_qual_flag_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:retrieval_qual_flag_pm',
#   'label': 'retrieval_qual_flag_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:retrieval_qual_flag_scah_pm',
#   'label': 'retrieval_qual_flag_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:retrieval_qual_flag_scav_pm',
#   'label': 'retrieval_qual_flag_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:roughness_coefficient_dca_pm',
#   'label': 'roughness_coefficient_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:roughness_coefficient_pm',
#   'label': 'roughness_coefficient_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:roughness_coefficient_scah_pm',
#   'label': 'roughness_coefficient_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:roughness_coefficient_scav_pm',
#   'label': 'roughness_coefficient_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:soil_moisture_dca_pm',
#   'label': 'soil_moisture_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:soil_moisture_error_pm',
#   'label': 'soil_moisture_error_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:soil_moisture_pm',
#   'label': 'soil_moisture_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:soil_moisture_scah_pm',
#   'label': 'soil_moisture_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:soil_moisture_scav_pm',
#   'label': 'soil_moisture_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:static_water_body_fraction_pm',
#   'label': 'static_water_body_fraction_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:surface_flag_pm',
#   'label': 'surface_flag_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:surface_temperature_pm',
#   'label': 'surface_temperature_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:surface_water_fraction_mb_h_pm',
#   'label': 'surface_water_fraction_mb_h_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:surface_water_fraction_mb_v_pm',
#   'label': 'surface_water_fraction_mb_v_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_3_corrected_pm',
#   'label': 'tb_3_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_4_corrected_pm',
#   'label': 'tb_4_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_h_corrected_pm',
#   'label': 'tb_h_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_h_uncorrected_pm',
#   'label': 'tb_h_uncorrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_qual_flag_3_pm',
#   'label': 'tb_qual_flag_3_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_qual_flag_4_pm',
#   'label': 'tb_qual_flag_4_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_qual_flag_h_pm',
#   'label': 'tb_qual_flag_h_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_qual_flag_v_pm',
#   'label': 'tb_qual_flag_v_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_time_seconds_pm',
#   'label': 'tb_time_seconds_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_time_utc_pm',
#   'label': 'tb_time_utc_pm',
#   'selected': 'false',
#   'excludeFormat': 'GeoTIFF,HDF-EOS5,KML,NetCDF-3',
#   'excludeProjection': 'GEOGRAPHIC,NO_CHANGE,NORTH POLAR STEREOGRAPHIC,SOUTH POLAR STEREOGRAPHIC,UNIVERSAL TRANSVERSE MERCATOR',
#   'compoundRule': 'true'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_v_corrected_pm',
#   'label': 'tb_v_corrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:tb_v_uncorrected_pm',
#   'label': 'tb_v_uncorrected_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:vegetation_opacity_dca_pm',
#   'label': 'vegetation_opacity_dca_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:vegetation_opacity_pm',
#   'label': 'vegetation_opacity_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:vegetation_opacity_scah_pm',
#   'label': 'vegetation_opacity_scah_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:vegetation_opacity_scav_pm',
#   'label': 'vegetation_opacity_scav_pm',
#   'selected': 'false'},
#  {'value': 'Soil_Moisture_Retrieval_Data_Polar_PM:vegetation_water_content_pm',
#   'label': 'vegetation_water_content_pm',
#   'selected': 'false'}]

# %% [markdown]
# ### Select subsetting, reformatting, and reprojection service options, if available.

# %%
#print service information depending on service availability and select service options
if len(subagent) < 1 :
    print('No services exist for', short_name, 'version', latest_version)
    agent = 'NO'
    bbox = ''
    time_var = ''
    reformat = ''
    projection = ''
    projection_parameters = ''
    coverage = ''
    Boundingshape = ''
else:
    # These reformatting options are available: ['HDF-EOS5', 'NetCDF4-CF', 'ASCII', 'KML', 'GeoTIFF']
    # These reprojection options are available with your requested format: ['GEOGRAPHIC', 'UNIVERSAL TRANSVERSE MERCATOR', 'CYLINDRICAL EQUAL AREA', 'NORTH POLAR STEREOGRAPHIC', 'SOUTH POLAR STEREOGRAPHIC']
    agent = ''
    subdict = subagent[0]
    if subdict['spatialSubsetting'] == 'true' and aoi == '1':
        Boundingshape = ''
        ss = 'n'
        if ss == 'y': bbox = bounding_box
        else: bbox = '' 
    if subdict['spatialSubsettingShapefile'] == 'true' and aoi == '2':
        bbox = ''
        # ps = input('Subsetting by geospatial file (Esri Shapefile, KML, etc.) is available. Would you like to request this service? (y/n)')
        if ps == 'y': Boundingshape = geojson
        else: Boundingshape = '' 
    if subdict['temporalSubsetting'] == 'true':
        ts = 'y'
        if ts == 'y': time_var = start_date + 'T' + start_time + ',' + end_date + 'T' + end_time 
        else: time_var = ''
    else: time_var = ''
    if len(format_vals) > 0 :
        print('These reformatting options are available:', format_vals)
        reformat = 'NetCDF4-CF'
        if reformat == 'n': reformat = '' # Catch user input of 'n' instead of leaving blank
    else: 
        reformat = ''
        projection = ''
        projection_parameters = ''
    if len(projections) > 0:
        valid_proj = [] # select reprojection options based on reformatting selection
        for i in range(len(projections)):
            if 'excludeFormat' in projections[i]:
                exclformats_str = projections[i]['excludeFormat'] 
                exclformats_list = exclformats_str.split(',')
            if ('excludeFormat' not in projections[i] or reformat not in exclformats_list) and projections[i]['value'] != 'NO_CHANGE': valid_proj.append(projections[i]['value'])
        if len(valid_proj) > 0:
            print('These reprojection options are available with your requested format:', valid_proj)
            projection = 'GEOGRAPHIC' #input('If you would like to reproject, copy and paste the reprojection option you would like (make sure to omit quotes), otherwise leave blank.')
            # Enter required parameters for UTM North and South
            if projection == 'UTM NORTHERN HEMISPHERE' or projection == 'UTM SOUTHERN HEMISPHERE': 
                # NZone = input('Please enter a UTM zone (1 to 60 for Northern Hemisphere; -60 to -1 for Southern Hemisphere):')
                projection_parameters = str('NZone:' + NZone)
            else: projection_parameters = ''
        else: 
            print('No reprojection options are supported with your requested format')
            projection = ''
            projection_parameters = ''
    else:
        print('No reprojection options are supported with your requested format')
        projection = ''
        projection_parameters = ''
        
# Select variable subsetting
if len(subagent) > 0 :
    if len(variable_vals) > 0:
        v = 'y'
        if v == 'y':
            print('The', short_name, 'variables to select from include:')
            coverage = \
            '/Soil_Moisture_Retrieval_Data_AM/soil_moisture,\
                /Soil_Moisture_Retrieval_Data_AM/retrieval_qual_flag,\
                    /Soil_Moisture_Retrieval_Data_AM/longitude,\
                        /Soil_Moisture_Retrieval_Data_AM/latitude,\
                            /Soil_Moisture_Retrieval_Data_AM/EASE_column_index,\
                                /Soil_Moisture_Retrieval_Data_AM/EASE_row_index,\
            /Soil_Moisture_Retrieval_Data_PM/soil_moisture_pm,\
                /Soil_Moisture_Retrieval_Data_PM/retrieval_qual_flag_pm,\
                    /Soil_Moisture_Retrieval_Data_PM/latitude_pm,\
                        /Soil_Moisture_Retrieval_Data_PM/longitude_pm,\
                            /Soil_Moisture_Retrieval_Data_PM/EASE_column_index_pm,\
                                /Soil_Moisture_Retrieval_Data_PM/EASE_row_index_pm'
        else: coverage = ''

#no services selected
if reformat == '' and projection == '' and projection_parameters == '' and coverage == '' and time_var == '' and bbox == '' and Boundingshape == '':
    agent = 'NO'
coverage
# Out:
# These reformatting options are available: ['HDF-EOS5', 'NetCDF4-CF', 'ASCII', 'KML', 'GeoTIFF']
# These reprojection options are available with your requested format: ['GEOGRAPHIC', 'UNIVERSAL TRANSVERSE MERCATOR', 'CYLINDRICAL EQUAL AREA', 'NORTH POLAR STEREOGRAPHIC', 'SOUTH POLAR STEREOGRAPHIC']
# The SPL3SMP_E variables to select from include:
# '/Soil_Moisture_Retrieval_Data_AM/soil_moisture,                /Soil_Moisture_Retrieval_Data_AM/retrieval_qual_flag,                    /Soil_Moisture_Retrieval_Data_AM/longitude,                        /Soil_Moisture_Retrieval_Data_AM/latitude,                            /Soil_Moisture_Retrieval_Data_AM/EASE_column_index,                                /Soil_Moisture_Retrieval_Data_AM/EASE_row_index,            /Soil_Moisture_Retrieval_Data_PM/soil_moisture_pm,                /Soil_Moisture_Retrieval_Data_PM/retrieval_qual_flag_pm,                    /Soil_Moisture_Retrieval_Data_PM/latitude_pm,                        /Soil_Moisture_Retrieval_Data_PM/longitude_pm,                            /Soil_Moisture_Retrieval_Data_PM/EASE_column_index_pm,                                /Soil_Moisture_Retrieval_Data_PM/EASE_row_index_pm'

# %% [markdown]
# Because variable subsetting can include a long list of variables to choose from, we will decide on variable subsetting separately from the service options above.

# %% [markdown]
# ### Select data access configurations
#
# The data request can be accessed asynchronously or synchronously. The asynchronous option will allow concurrent requests to be queued and processed without the need for a continuous connection. Those requested orders will be delivered to the specified email address, or they can be accessed programmatically as shown below. Synchronous requests will automatically download the data as soon as processing is complete. The granule limits differ between these two options:
#
# Maximum granules per synchronous request = 100
#
# Maximum granules per asynchronous request = 2000
#
# We will set the access configuration depending on the number of granules requested. For requests over 2000 granules, we will produce multiple API endpoints for each 2000-granule order. Please note that synchronous requests may take a long time to complete depending on request parameters, so the number of granules may need to be adjusted if you are experiencing performance issues. The `page_size` parameter can be used to adjust this number.

# %%
#Set NSIDC data access base URL
base_url = 'https://n5eil02u.ecs.nsidc.org/egi/request'

#Set the request mode to asynchronous if the number of granules is over 100, otherwise synchronous is enabled by default
if len(granules) > 100:
    request_mode = 'async'
    page_size = 2000
else: 
    page_size = 100
    request_mode = 'stream'

#Determine number of orders needed for requests over 2000 granules. 
page_num = math.ceil(len(granules)/page_size)

print('There will be', page_num, 'total order(s) processed for our', short_name, 'request.')
# Out:
# There will be 1 total order(s) processed for our SPL3SMP_E request.

# %% [markdown]
# ### Create the API endpoint
#
# Programmatic API requests are formatted as HTTPS URLs that contain key-value-pairs specifying the service operations that we specified above. The following command can be executed via command line, a web browser, or in Python below.

# %%
if aoi == '1':
# bounding box search and subset:
    param_dict = {'short_name': short_name, 
                  'version': latest_version, 
                  'temporal': temporal, 
                  'time': time_var, 
                  'format': reformat, 
                  'projection': projection, 
                  'projection_parameters': projection_parameters, 
                  'Coverage': coverage, 
                  'page_size': page_size, 
                  'request_mode': request_mode, 
                  'agent': agent, 
                  'email': email, }

#Remove blank key-value-pairs
param_dict = {k: v for k, v in param_dict.items() if v != ''}

#Convert to string
param_string = '&'.join("{!s}={!r}".format(k,v) for (k,v) in param_dict.items())
param_string = param_string.replace("'","")

#Print API base URL + request parameters
endpoint_list = [] 
for i in range(page_num):
    page_val = i + 1
    API_request = api_request = f'{base_url}?{param_string}&page_num={page_val}'
    endpoint_list.append(API_request)

print(*endpoint_list, sep = "\n")
# Out:
# https://n5eil02u.ecs.nsidc.org/egi/request?short_name=SPL3SMP_E&version=005&temporal=2017-12-26T00:00:00Z,2020-10-26T00:00:00Z&format=NetCDF4-CF&projection=GEOGRAPHIC&Coverage=/Soil_Moisture_Retrieval_Data_AM/soil_moisture,                /Soil_Moisture_Retrieval_Data_AM/retrieval_qual_flag,                    /Soil_Moisture_Retrieval_Data_AM/longitude,                        /Soil_Moisture_Retrieval_Data_AM/latitude,                            /Soil_Moisture_Retrieval_Data_AM/EASE_column_index,                                /Soil_Moisture_Retrieval_Data_AM/EASE_row_index,            /Soil_Moisture_Retrieval_Data_PM/soil_moisture_pm,                /Soil_Moisture_Retrieval_Data_PM/retrieval_qual_flag_pm,                    /Soil_Moisture_Retrieval_Data_PM/latitude_pm,                        /Soil_Moisture_Retrieval_Data_PM/longitude_pm,                            /Soil_Moisture_Retrieval_Data_PM/EASE_column_index_pm,                                /Soil_Moisture_Retrieval_Data_PM/EASE_row_index_pm&page_size=2000&request_mode=async&email=raraki8159@sdsu.edu&page_num=1

# %% [markdown]
# ### Request data

# %% [markdown]
# We will now download data using the Python requests library. The data will be downloaded directly to this notebook directory in a new Outputs folder. The progress of each order will be reported.

# %%
# Create an output folder if the folder does not already exist.

path = os.path.join(out_path, short_name)
if not os.path.exists(path):
    os.mkdir(path)

# Different access methods depending on request mode:

if request_mode=='async':
    # Request data service for each page number, and unzip outputs
    
    for i in range(page_num):
        page_val = i + 1
        print('Order: ', page_val)

    # For all requests other than spatial file upload, use get function
        request = session.get(base_url, params=param_dict)

        print('Request HTTP response: ', request.status_code)

    # Raise bad request: Loop will stop for bad response code.
        request.raise_for_status()
        print('Order request URL: ', request.url)
        esir_root = ET.fromstring(request.content)
        print('Order request response XML content: ', request.content)

    #Look up order ID
        orderlist = []   
        for order in esir_root.findall("./order/"):
            orderlist.append(order.text)
        orderID = orderlist[0]
        print('order ID: ', orderID)

    #Create status URL
        statusURL = base_url + '/' + orderID
        print('status URL: ', statusURL)

    #Find order status
        request_response = session.get(statusURL)    
        print('HTTP response from order response URL: ', request_response.status_code)

    # Raise bad request: Loop will stop for bad response code.
        request_response.raise_for_status()
        request_root = ET.fromstring(request_response.content)
        statuslist = []
        for status in request_root.findall("./requestStatus/"):
            statuslist.append(status.text)
        status = statuslist[0]
        print('Data request ', page_val, ' is submitting...')
        print('Initial request status is ', status)

    #Continue loop while request is still processing
        while status == 'pending' or status == 'processing': 
            print('Status is not complete. Trying again.')
            time.sleep(10)
            loop_response = session.get(statusURL)

    # Raise bad request: Loop will stop for bad response code.
            loop_response.raise_for_status()
            loop_root = ET.fromstring(loop_response.content)

    #find status
            statuslist = []
            for status in loop_root.findall("./requestStatus/"):
                statuslist.append(status.text)
            status = statuslist[0]
            print('Retry request status is: ', status)
            if status == 'pending' or status == 'processing':
                continue

    #Order can either complete, complete_with_errors, or fail:
    # Provide complete_with_errors error message:
        if status == 'complete_with_errors' or status == 'failed':
            messagelist = []
            for message in loop_root.findall("./processInfo/"):
                messagelist.append(message.text)
            print('error messages:')
            pprint.pprint(messagelist)

    # Download zipped order if status is complete or complete_with_errors
        if status == 'complete' or status == 'complete_with_errors':
            try:
                downloadURL = 'https://n5eil02u.ecs.nsidc.org/esir/' + orderID
                print('Zip download URL: ', downloadURL)
                print('Beginning download of zipped output...')
                zip_response = session.get(downloadURL)
                # Raise bad request: Loop will stop for bad response code.
                zip_response.raise_for_status()
                with zipfile.ZipFile(io.BytesIO(zip_response.content)) as z:
                    z.extractall(path)
            except:
                for nzip in range(1,5):
                    downloadURL = 'https://n5eil02u.ecs.nsidc.org/esir/' + orderID + '.zip?' +  str(nzip)
                    print('Zip download URL: ', downloadURL)
                    print('Beginning download of zipped output...')
                    zip_response = session.get(downloadURL)
                    # Raise bad request: Loop will stop for bad response code.
                    zip_response.raise_for_status()
                    with zipfile.ZipFile(io.BytesIO(zip_response.content)) as z:
                        z.extractall(path)
                print('Data request', page_val, 'is complete.')
        else: print('Request failed.')
            
else:
    for i in range(page_num):
        page_val = i + 1
        print('Order: ', page_val)
        print('Requesting...')
        request = session.get(base_url, params=param_dict)
        print('HTTP response from order response URL: ', request.status_code)
        request.raise_for_status()
        d = request.headers['content-disposition']
        fname = re.findall('filename=(.+)', d)
        dirname = os.path.join(path,fname[0].strip('\"'))
        print('Downloading...')
        open(dirname, 'wb').write(request.content)
        print('Data request', page_val, 'is complete.')
    
    # Unzip outputs
    for z in os.listdir(path): 
        if z.endswith('.zip'): 
            zip_name = path + "/" + z 
            zip_ref = zipfile.ZipFile(zip_name) 
            zip_ref.extractall(path) 
            zip_ref.close() 
            os.remove(zip_name)
# Out:
# Order:  1
# Request HTTP response:  201
# Order request URL:  https://n5eil02u.ecs.nsidc.org/egi/request?short_name=SPL3SMP_E&version=005&temporal=2017-12-26T00%3A00%3A00Z%2C2020-10-26T00%3A00%3A00Z&format=NetCDF4-CF&projection=GEOGRAPHIC&Coverage=%2FSoil_Moisture_Retrieval_Data_AM%2Fsoil_moisture%2C++++++++++++++++%2FSoil_Moisture_Retrieval_Data_AM%2Fretrieval_qual_flag%2C++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_AM%2Flongitude%2C++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_AM%2Flatitude%2C++++++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_AM%2FEASE_column_index%2C++++++++++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_AM%2FEASE_row_index%2C++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2Fsoil_moisture_pm%2C++++++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2Fretrieval_qual_flag_pm%2C++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2Flatitude_pm%2C++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2Flongitude_pm%2C++++++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2FEASE_column_index_pm%2C++++++++++++++++++++++++++++++++%2FSoil_Moisture_Retrieval_Data_PM%2FEASE_row_index_pm&page_size=2000&request_mode=async&email=raraki8159%40sdsu.edu
# Order request response XML content:  b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<eesi:agentResponse xmlns="" xmlns:iesi="http://eosdis.nasa.gov/esi/rsp/i" xmlns:ssw="http://newsroom.gsfc.nasa.gov/esi/rsp/ssw" xmlns:eesi="http://eosdis.nasa.gov/esi/rsp/e" xmlns:esi="http://eosdis.nasa.gov/esi/rsp" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n    <order>\n        <orderId>5000003983686</orderId>\n        <Instructions>You may receive an email about your order if you specified an EMAIL address. &lt;br/&gt;&lt;br/&gt;The instructions used to process this order are:  Projection=GEOGRAPHIC. Output file format=NetCDF4-CF. Band(s)=/Soil_Moisture_Retrieval_Data_AM/soil_moisture,                /Soil_Moisture_Retrieval_Data_AM/retrieval_qual_flag,                    /Soil_Moisture_Retrieval_Data_AM/longitude,                        /Soil_Moisture_Retrieval_Data_AM/latitude,                            /Soil_Moisture_Retrieval_Data_AM/EASE_column_index,                                /Soil_Moisture_Retrieval_Data_AM/EASE_row_index,            /Soil_Moisture_Retrieval_Data_PM/soil_moisture_pm,                /Soil_Moisture_Retrieval_Data_PM/retrieval_qual_flag_pm,                    /Soil_Moisture_Retrieval_Data_PM/latitude_pm,                        /
SMP_E.005:240888687,SC:SPL3SMP_E.005:240848346,SC:SPL3SMP_E.005:240875926,SC:SPL3SMP_E.005:240890603,SC:SPL3SMP_E.005:240855836,SC:SPL3SMP_E.005:240876845,SC:SPL3SMP_E.005:240896335,SC:SPL3SMP_E.005:240877702,SC:SPL3SMP_E.005:240896337,SC:SPL3SMP_E.005:240865294,SC:SPL3SMP_E.005:240884465,SC:SPL3SMP_E.005:240856192,SC:SPL3SMP_E.005:240882971,SC:SPL3SMP_E.005:240890931,SC:SPL3SMP_E.005:240884482,SC:SPL3SMP_E.005:240883256,SC:SPL3SMP_E.005:240851096,SC:SPL3SMP_E.005:240884628,SC:SPL3SMP_E.005:240848352,SC:SP ...
# order ID:  5000003983686
# status URL:  https://n5eil02u.ecs.nsidc.org/egi/request/5000003983686
# HTTP response from order response URL:  201
# Data request  1  is submitting...
# Initial request status is  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  processing
# Status is not complete. Trying again.
# Retry request status is:  complete
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000003983686
# Beginning download of zipped output...
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000003983686.zip?1
# Beginning download of zipped output...
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000003983686.zip?2
# Beginning download of zipped output...
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In [52], line 89
#      88 zip_response.raise_for_status()
# ---> 89 with zipfile.ZipFile(io.BytesIO(zip_response.content)) as z:
#      90     z.extractall(path)
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\zipfile.py:1267, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1266 if mode == 'r':
# -> 1267     self._RealGetContents()
#    1268 elif mode in ('w', 'x'):
#    1269     # set the modified flag so central directory gets written
#    1270     # even if no files are added to the archive
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\zipfile.py:1334, in ZipFile._RealGetContents(self)
#    1333 if not endrec:
# -> 1334     raise BadZipFile("File is not a zip file")
#    1335 if self.debug > 1:
#
# BadZipFile: File is not a zip file
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [52], line 96
#      94 print('Zip download URL: ', downloadURL)
#      95 print('Beginning download of zipped output...')
# ---> 96 zip_response = session.get(downloadURL)
#      97 # Raise bad request: Loop will stop for bad response code.
#      98 zip_response.raise_for_status()
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\urllib3\response.py:623, in HTTPResponse.stream(self, amt, decode_content)
#     607 """
#     608 A generator wrapper for the read() method. A call will block until
#     609 ``amt`` bytes have been read from the connection or until the
#    (...)
#     620     'content-encoding' header.
#     621 """
#     622 if self.chunked and self.supports_chunked_reads():
# --> 623     for line in self.read_chunked(amt, decode_content=decode_content):
#     624         yield line
#     625 else:
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\urllib3\response.py:818, in HTTPResponse.read_chunked(self, amt, decode_content)
#     816 if self.chunk_left == 0:
#     817     break
# --> 818 chunk = self._handle_chunk(amt)
#     819 decoded = self._decode(
#     820     chunk, decode_content=decode_content, flush_decoder=False
#     821 )
#     822 if decoded:
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib\site-packages\urllib3\response.py:762, in HTTPResponse._handle_chunk(self, amt)
#     760     self.chunk_left = None
#     761 elif amt < self.chunk_left:
# --> 762     value = self._fp._safe_read(amt)
#     763     self.chunk_left = self.chunk_left - amt
#     764     returned_chunk = value
#
# File c:\USERS\RARAKI8159\.CONDA\ENVS\SMAP\lib
R18290_001_HEGOUT.nc
# SMAP_L3_SM_P_E_20220329_R18290_001_HEGOUT.nc
# SMAP_L3_SM_P_E_20220330_R18290_001_HEGOUT.nc

# %%
import os
import datetime

def is_complete(folder):
    # Create a set to store the dates for which we've seen a file
    seen_dates = set()
    
    # Loop through the files in the folder
    for file in os.listdir(folder):
        # Check if the file name matches the pattern
        if not file.startswith("SMAP_L3_SM_P_E_") or not file.endswith("_HEGOUT.nc"):
            continue
        
        # Extract the date from the file name
        date_str = file[15:23]
        # print(date_str)
        try:
            date = datetime.datetime.strptime(date_str, "%Y%m%d").date()
        except ValueError:
            continue
        
        # Add the date to the set of seen dates
        seen_dates.add(date)
        
    # Create a set of all the dates from 2015 to 2022
    all_dates = set()
    start_date = datetime.date(2015, 3, 31)
    end_date = datetime.date(2022, 3, 30)
    current_date = start_date
    while current_date <= end_date:
        all_dates.add(current_date)
        current_date += datetime.timedelta(days=1)
    
    # Find the missing dates
    missing_dates = all_dates - seen_dates
    # print(seen_dates)
    # Check if the set of seen dates is equal to the set of all dates
    if missing_dates:
        print("Missing dates:")
        for date in sorted(missing_dates):
            print(date)
    else:
        return True
    return False

if is_complete(path):
    print("Daily data is complete from March 31, 2015 to March 30, 2022.")
else:
    print("Daily data is not complete from March 31, 2015 to March 30, 2022.")
# Out:
# Missing dates:
# 2015-01-01
# 2015-01-02
# 2015-01-03
# 2015-01-04
# 2015-01-05
# 2015-01-06
# 2015-01-07
# 2015-01-08
# 2015-01-09
# 2015-01-10
# 2015-01-11
# 2015-01-12
# 2015-01-13
# 2015-01-14
# 2015-01-15
# 2015-01-16
# 2015-01-17
# 2015-01-18
# 2015-01-19
# 2015-01-20
# 2015-01-21
# 2015-01-22
# 2015-01-23
# 2015-01-24
# 2015-01-25
# 2015-01-26
# 2015-01-27
# 2015-01-28
# 2015-01-29
# 2015-01-30
# 2015-01-31
# 2015-02-01
# 2015-02-02
# 2015-02-03
# 2015-02-04
# 2015-02-05
# 2015-02-06
# 2015-02-07
# 2015-02-08
# 2015-02-09
# 2015-02-10
# 2015-02-11
# 2015-02-12
# 2015-02-13
# 2015-02-14
# 2015-02-15
# 2015-02-16
# 2015-02-17
# 2015-02-18
# 2015-02-19
# 2015-02-20
# 2015-02-21
# 2015-02-22
# 2015-02-23
# 2015-02-24
# 2015-02-25
# 2015-02-26
# 2015-02-27
# 2015-02-28
# 2015-03-01
# 2015-03-02
# 2015-03-03
# 2015-03-04
# 2015-03-05
# 2015-03-06
# 2015-03-07
# 2015-03-08
# 2015-03-09
# 2015-03-10
# 2015-03-11
# 2015-03-12
# 2015-03-13
# 2015-03-14
# 2015-03-15
# 2015-03-16
# 2015-03-17
# 2015-03-18
# 2015-03-19
# 2015-03-20
# 2015-03-21
# 2015-03-22
# 2015-03-23
# 2015-03-24
# 2015-03-25
# 2015-03-26
# 2015-03-27
# 2015-03-28
# 2015-03-29
# 2015-03-30
# 2015-05-13
# 2015-12-16
# 2016-05-01
# 2016-09-27
# 2019-06-20
# 2019-06-21
# 2019-06-22
# 2019-06-23
# 2019-06-24
# 2019-06-25
# 2019-06-26
# 2019-06-27
# 2019-06-28
# 2019-06-29
# 2019-06-30
# 2019-07-01
# 2019-07-02
# 2019-07-03
# 2019-07-04
# 2019-07-05
# 2019-07-06
# 2019-07-07
# 2019-07-08
# 2019-07-09
# 2019-07-10
# 2019-07-11
# 2019-07-12
# 2019-07-13
# 2019-07-14
# 2019-07-15
# 2019-07-16
# 2019-07-17
# 2019-07-18
# 2019-07-19
# 2019-07-20
# 2019-07-21
# 2019-07-22
# 2022-03-31
# 2022-04-01
# 2022-04-02
# 2022-04-03
# 2022-04-04
# 2022-04-05
# 2022-04-06
# 2022-04-07
# 2022-04-08
# 2022-04-09
# 2022-04-10
# 2022-04-11
# 2022-04-12
# 2022-04-13
# 2022-04-14
# 2022-04-15
# 2022-04-16
# 2022-04-17
# 2022-04-18
# 2022-04-19
# 2022-04-20
# 2022-04-21
# 2022-04-22
# 2022-04-23
# 2022-04-24
# 2022-04-25
# 2022-04-26
# 2022-04-27
# 2022-04-28
# 2022-04-29
# 2022-04-30
# 2022-05-01
# 2022-05-02
# 2022-05-03
# 2022-05-04
# 2022-05-05
# 2022-05-06
# 2022-05-07
# 2022-05-08
# 2022-05-09
# 2022-05-10
# 2022-05-11
# 2022-05-12
# 2022-05-13
# 2022-05-14
# 2022-05-15
# 2022-05-16
# 2022-05-17
# 2022-05-18
# 2022-05-19
# 2022-05-20
# 2022-05-21
# 2022-05-22
# 2022-05-23
# 2022-05-24
# 2022-05-25
# 2022-05-26
# 2022-05-27
# 2022-05-28
# 2022-05-29
# 2022-05-30
# 2022-05-31
# 2022-06-01
# 2022-06-02
# 2022-06-03
# 2022-06-04
# 2022-06-05
# 2022-06-06
# 2022-06-07
# 2022-06-08
# 2022-06-09
# 2022-06-10
# 2022-06-11
# 2022-06-12
# 2022-06-13
# 2022-06-14
# 2022-06-15
# 2022-06-16
# 2022-06-17
# 2022-06-18
# 2022-06-19
# 2022-06-20
# 2022-06-21
# 2022-06-22
# 2022-06-23
# 2022-06-24
# 2022-06-25
# 2022-06-26
# 2022-06-27
# 2022-06-28
# 2022-06-29
# 2022-06-30
# 2022-07-01
# 2022-07-02
# 2022-07-03
# 2022-07-04
# 2022-07-05
# 2022-07-06
# 2022-07-07
# 2022-07-08
# 2022-07-09
# 2022-07-10
# 2022-07-11
# 2022-07-12
# 2022-07-13
# 2022-07-14
# 2022-07-15
# 2022-07-16
# 2022-07-17
# 2022-07-18
# 2022-07-19
# 2022-07-20
# 2022-07-21
# 2022-07-22
# 2022-07-23
# 2022-07-24
# 2022-07-25
# 2022-07-26
# 2022-07-27
# 2022-07-28
# 2022-07-29
# 2022-07-30
# 2022-07-31
# 2022-08-01
# 2022-08-02
# 2022-08-03
# 2022-08-04
# 2022-08-05
# 2022-08-06
# 2022-08-07
# 2022-08-08
# 2022-08-09
# 2022-08-10
# 2022-08-11
# 2022-08-12
# 2022-08-13
# 2022-08-14
# 2022-08-15
# 2022-08-16
# 2022-08-17
# 2022-08-18
# 2022-08-19
# 2022-08-20
# 2022-08-21
# 2022-08-22
# 2022-08-23
# 2022-08-24
# 2022-08-25
# 2022-08-26
# 2022-08-27
# 2022-08-28
# 2022-08-29
# 2022-08-30
# 2022-08-31
# 2022-09-01
# 2022-09-02
# 2022-09-03
# 2022-09-04
# 2022-09-05
# 2022-09-06
# 2022-09-07
# 2022-09-08
# 2022-09-09
# 2022-09-10
# 2022-09-11
# 2022-09-12
# 2022-09-13
# 2022-09-14
# 2022-09-15
# 2022-09-16
# 2022-09-17
# 2022-09-18
# 2022-09-19
# 2022-09-20
# 2022-09-21
# 2022-09-22
# 2022-09-23
# 2022-09-24
# 2022-09-25
# 2022-09-26
# 2022-09-27
# 2022-09-28
# 2022-09-29
# 2022-09-30
# 2022-10-01
# 2022-10-02
# 2022-10-03
# 2022-10-04
# 2022-10-05
# 2022-10-06
# 2022-10-07
# 2022-10-08
# 2022-10-09
# 2022-10-10
# 2022-10-11
# 2022-10-12
# 2022-10-13
# 2022-10-14
# 2022-10-15
# 2022-10-16
# 2022-10-17
# 2022-10-18
# 2022-10-19
# 2022-10-20
# 2022-10-21
# 2022-10-22
# 2022-10-23
# 2022-10-24
# 2022-10-25
# 2022-10-26
# 2022-10-27
# 2022-10-28
# 2022-10-29
# 2022-10-30
# 2022-10-31
# 2022-11-01
# 2022-11-02
# 2022-11-03
# 2022-11-04
# 2022-11-05
# 2022-11-06
# 2022-11-07
# 2022-11-08
# 2022-11-09
# 2022-11-10
# 2022-11-11
# 2022-11-12
# 2022-11-13
# 2022-11-14
# 2022-11-15
# 2022-11-16
# 2022-11-17
# 2022-11-18
# 2022-11-19
# 2022-11-20
# 2022-11-21
# 2022-11-22
# 2022-11-23
# 2022-11-24
# 2022-11-25
# 2022-11-26
# 2022-11-27
# 2022-11-28
# 2022-11-29
# 2022-11-30
# 2022-12-01
# 2022-12-02
# 2022-12-03
# 2022-12-04
# 2022-12-05
# 2022-12-06
# 2022-12-07
# 2022-12-08
# 2022-12-09
# 2022-12-10
# 2022-12-11
# 2022-12-12
# 2022-12-13
# 2022-12-14
# 2022-12-15
# 2022-12-16
# 2022-12-17
# 2022-12-18
# 2022-12-19
# 2022-12-20
# 2022-12-21
# 2022-12-22
# 2022-12-23
# 2022-12-24
# 2022-12-25
# 2022-12-26
# 2022-12-27
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2022-12-31
# Daily data is not complete from 2015 to 2022.

# %%
print(all_dates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 print(all_dates)
#
# NameError: name 'all_dates' is not defined

# %% [markdown]
# ### To review, we have explored data availability and volume over a region and time of interest, discovered and selected data customization options, constructed an API endpoint for our request, and downloaded data directly to our local machine. You are welcome to request different data sets, areas of interest, and/or customization services by re-running the notebook or starting again at the 'Select a data set of interest' step above.
