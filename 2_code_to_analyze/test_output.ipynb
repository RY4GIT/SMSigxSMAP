# %%
import xarray as xr

# %%
out_path = r"G:\Araki\SMSigxSMAP\3_data_out\a_diff_202303\results.nc"
ds = xr.open_dataset(out_path)

# %%
ds.a_diff.plot()

# %%
ds.MSE_upper.plot()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (x: 113, y: 107)
# Coordinates:
#   * x          (x) float64 -124.5 -124.4 -124.3 -124.2 ... -114.2 -114.1 -114.0
#   * y          (y) float64 42.43 42.33 42.24 42.15 ... 32.81 32.72 32.62 32.53
# Data variables:
#     a_diff     (y, x) float64 ...
#     a_upper    (y, x) float64 ...
#     a_lower    (y, x) float64 ...
#     MSE_upper  (y, x) float64 ...
#     MSE_lower  (y, x) float64 ...
#     PET_upper  (y, x) float64 ...
#     PET_lower  (y, x) float64 ...
#     meanSM     (y, x) float32 ...
#     meanP      (y, x) float32 ...
