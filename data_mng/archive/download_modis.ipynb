# %%
from modis_tools.auth import ModisSession
from modis_tools.resources import CollectionApi, GranuleApi
from modis_tools.granule_handler import GranuleHandler
import json 

my_credential_path = "./auth.json"
with open(my_credential_path, 'r') as infile:
    my_credentials = json.load(infile)

username = my_credentials['username']  # Update this line
password = my_credentials['password']  # Update this line

# Authenticate a session
session = ModisSession(username=username, password=password)

# Query the MODIS catalog for collections
collection_client = CollectionApi(session=session)
collections = collection_client.query(short_name="MOD15A2H", version="061")

# Query the selected collection for granules
granule_client = GranuleApi.from_collection(collections[0], session=session)

# Filter the selected granules via spatial and temporal parameters
nigeria_bbox = [2.1448863675, 4.002583177, 15.289420717, 14.275061098]
nigeria_granules = granule_client.query(start_date="2016-01-01", end_date="2018-12-31", bounding_box=nigeria_bbox)

# %%
GranuleHandler.download_from_granules(nigeria_granules, session)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 GranuleHandler.download_from_granules(nigeria_granules, session)
#
# File c:\Users\flipl\anaconda3\envs\SMAP\lib\site-packages\modis_tools\granule_handler.py:55, in GranuleHandler.download_from_granules(cls, one_or_many_granules, modis_session, threads, path, force)
#      32 """Download the corresponding raster file for each item in `granules`
#      33
#      34 Args:
#    (...)
#      52     List[str]: Path to the newly downloaded file(s)
#      53 """
#      54 granules = cls._coerce_to_list(one_or_many_granules, Granule)
# ---> 55 urls = [cls.get_url_from_granule(x, "hdf") for x in granules]
#      56 if threads in (None, 0, 1):
#      57     return cls.download_from_urls(
#      58         urls, modis_session=modis_session, path=path, force=force, disable=False
#      59     )
#
# File c:\Users\flipl\anaconda3\envs\SMAP\lib\site-packages\modis_tools\granule_handler.py:55, in <listcomp>(.0)
#      32 """Download the corresponding raster file for each item in `granules`
#      33
#      34 Args:
#    (...)
#      52     List[str]: Path to the newly downloaded file(s)
#      53 """
#      54 granules = cls._coerce_to_list(one_or_many_granules, Granule)
# ---> 55 urls = [cls.get_url_from_granule(x, "hdf") for x in granules]
#      56 if threads in (None, 0, 1):
#      57     return cls.download_from_urls(
#      58         urls, modis_session=modis_session, path=path, force=force, disable=False
#      59     )
#
# File c:\Users\flipl\anaconda3\envs\SMAP\lib\site-packages\modis_tools\resources.py:119, in GranuleApi.query(self, start_date, end_date, time_delta, spatial, bounding_box, limit, **kwargs)
#     117     resp = self.no_auth.get(params=params, auth=None)
#     118     feed = resp.json()["feed"]
# --> 119     granule_feed = GranuleFeed(**feed)
#     120 except (json.JSONDecodeError, KeyError, IndexError) as err:
#     121     raise Exception("Can't read response") from err
#
# File c:\Users\flipl\anaconda3\envs\SMAP\lib\site-packages\pydantic\main.py:342, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 2208 validation errors for GranuleFeed
# entry -> 0 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 0 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 0 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 0 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 1 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 1 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 1 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 1 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 2 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 2 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 2 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 2 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 3 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 3 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 3 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 3 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 4 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 4 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 4 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 4 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 5 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 5 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 5 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 5 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 6 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 6 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 6 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 6 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 7 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 7 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 7 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 7 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 8 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 8 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 8 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 8 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 9 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 9 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 9 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 9 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 10 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 10 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 10 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 10 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 11 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 11 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 11 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 11 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 12 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 12 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 12 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 12 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 13 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 13 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 13 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 13 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 14 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 14 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 14 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 14 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 15 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 15 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 15 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 15 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 16 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 16 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 16 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 16 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 17 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 17 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 17 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 17 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 18 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 18 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 18 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 18 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 19 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 19 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 19 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 19 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 20 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 20 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 20 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 20 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 21 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 21 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 21 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 21 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 22 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 22 -> links -> 4 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 22 -> links -> 7 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 22 -> links -> 9 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry -> 23 -> links -> 1 -> href
#   URL scheme not permitted (type=value_error.url.scheme; allowed_schemes={'https', 'http'})
# entry ->